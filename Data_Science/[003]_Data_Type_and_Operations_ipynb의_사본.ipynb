# %% [markdown]
# <a href="https://colab.research.google.com/github/Calcious98/TIL/blob/master/%5B003%5D_Data_Type_and_Operations_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Data Type & Operations

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # I. Python Function

# %% [markdown]
# > ## 1) 함수 실행

# %% [markdown]
# * print( ) 실행

# %%
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# * 매개변수(Parameter) 및 인자/인수(Argument) 지정

# %%
print('Hello World', end = '\t')
# Out:
# Hello World

# %%
print('Hello', 'World', sep = '-')
# Out:
# Hello-World

# %% [markdown]
# * 내장 매뉴얼

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(...)
#     print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
#     Prints the values to a stream, or to sys.stdout by default.
#     Optional keyword arguments:
#     file:  a file-like object (stream); defaults to the current sys.stdout.
#     sep:   string inserted between values, default a space.
#     end:   string appended after the last value, default a newline.
#     flush: whether to forcibly flush the stream.

# %% [markdown]
# > ## 2) 객체(Object) 선언
#
#  - <font color = 'blue'>파이썬 식별자(Identifiers)는 객체, 함수, 클래스, 모듈 또는 다른 개체 식별에 사용되는 이름</font>
#  - 식별자는 문자(A-Z, a-z)로 시작하고 밑줄(_), 숫자(0~9)를 사용
#  - 특수문자 @, $, %는 식별자로 사용할 수 없음
#  - 파이썬은 대소문자를 구분

# %%
koo = 'Data Analytics'
print(koo)
# Out:
# Data Analytics

# %%
type(koo)
# Out:
# str

# %% [markdown]
# * 예약어(35개)
#  - <font color = 'red'>객체명으로 사용할 수 없음

# %%
import keyword

keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %% [markdown]
# # II. Python Data Type

# %% [markdown]
# > ## 1) Numeric

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * 정수

# %%
print(888)
print(type(888))
# Out:
# 888
# <class 'int'>

# %% [markdown]
# * 8진수

# %%
print(0o77)
print(type(0o77))
# Out:
# 63
# <class 'int'>

# %% [markdown]
# * 16진수

# %%
print(0xff)
print(type(0xff))
# Out:
# 255
# <class 'int'>

# %% [markdown]
# * 2진수

# %%
print(0b1001)
print(type(0b1001))
# Out:
# 9
# <class 'int'>

# %% [markdown]
# * 실수

# %%
print(3.14)
print(type(3.14))
# Out:
# 3.14
# <class 'float'>

# %% [markdown]
# * 과학적 표기법

# %%
print(5e-4)
print(type(5e-4))
# Out:
# 0.0005
# <class 'float'>

# %%
print(5e+4)
print(type(5e+4))
# Out:
# 50000.0
# <class 'float'>

# %% [markdown]
# * 복소수(Complex)

# %%
print(8 + 9j)
print(type(8 + 9j))
# Out:
# (8+9j)
# <class 'complex'>

# %% [markdown]
# > ## 2) String

# %%
print('A')
print(type('A'))
# Out:
# A
# <class 'str'>

# %%
print('Data Analytics')
print(type('Data Analytics'))
# Out:
# Data Analytics
# <class 'str'>

# %% [markdown]
# > ## 3) Logical

# %% [markdown]
# * 참(True)
# * 거짓(False)

# %%
print(True)
print(type(True))
# Out:
# True
# <class 'bool'>

# %%
print(False)
print(type(False))
# Out:
# False
# <class 'bool'>

# %% [markdown]
# # III. 산술연산(Arithmetic Operators)

# %% [markdown]
# > ## 1) 사칙연산

# %% [markdown]
# * 덧셈

# %%
8 + 9
# Out:
# 17

# %% [markdown]
# * 뺄셈

# %%
8 - 9
# Out:
# -1

# %% [markdown]
# * 곱셈

# %%
8 * 9
# Out:
# 72

# %% [markdown]
# * 실수 나눗셈

# %%
10 / 3
# Out:
# 3.3333333333333335

# %% [markdown]
# * 나눗셈 후 몫 반환

# %%
10 // 3
# Out:
# 3.0

# %% [markdown]
# * 나눗셈 후 나머지 반환

# %%
10 % 3
# Out:
# 1

# %% [markdown]
# * 제곱

# %%
9 ** 3
# Out:
# 729

# %%
pow(9, 2)
# Out:
# 81

# %% [markdown]
# > ## 2) 절댓값

# %%
abs(-3)
# Out:
# 3

# %% [markdown]
# > ## 3) 진법 변환

# %% [markdown]
# * 16진수

# %%
hex(16)
# Out:
# '0x10'

# %% [markdown]
# * 8진수

# %%
oct(8)
# Out:
# '0o10'

# %% [markdown]
# * 2진수

# %%
bin(9)
# Out:
# '0b1001'

# %% [markdown]
# > ## 4) 반올림

# %% [markdown]
# * round(number[, ndigits])

# %%
round(24.47)
# Out:
# 24

# %%
round(24.57)
# Out:
# 25

# %%
round(24.57, ndigits = 0)
# Out:
# 25.0

# %%
round(24.57, ndigits = 1)
# Out:
# 24.6

# %%
round(24.57, ndigits = -1)
# Out:
# 20.0

# %%
round(25.47, ndigits = -1)
# Out:
# 30.0

# %%
round(25.478, ndigits = 2)
# Out:
# 25.48

# %% [markdown]
# # IV. 비교 연산자(Comparison Operators)

# %% [markdown]
# > ## 1) Numeric

# %%
8 > 9
# Out:
# False

# %%
8 < 9
# Out:
# True

# %%
8 >= 9
# Out:
# False

# %%
8 <= 9
# Out:
# True

# %%
8 == 9
# Out:
# False

# %%
8 != 9
# Out:
# True

# %% [markdown]
# > ## 2) Character

# %% [markdown]
# * 동작-1

# %%
'A' > 'B'
# Out:
# False

# %% [markdown]
# * 동작-2

# %%
'A' < 'B'
# Out:
# True

# %%
'A' == 'B'
# Out:
# False

# %%
'A' != 'B'
# Out:
# True

# %% [markdown]
# * <font color = 'red'>Error-1

# %%
'팔' > 9
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-74-8dbbd53735b8> in <module>()
# ----> 1 '팔' > 9
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %% [markdown]
# * <font color = 'red'>Error-2

# %%
'A' > 9
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-75-41e11a074f7f> in <module>()
# ----> 1 'A' > 9
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %% [markdown]
# # V. 논리 연산자(Logical Operators)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
X = True
Y = False
Z = True

print(X, Y, Z)
# Out:
# True False True

# %% [markdown]
# > ## 1) AND

# %%
X and Y
# Out:
# False

# %% [markdown]
# > ## 2) OR

# %%
X or Y
# Out:
# True

# %% [markdown]
# > ## 3) NOT

# %%
not X
# Out:
# False

# %% [markdown]
# > ## 4) 괄호 연산자

# %%
(X and Y) and (Y or Z)
# Out:
# False

# %% [markdown]
# #
# #
# #
# # The End
# #
# #
# #

# %% [markdown]
# <a href="https://colab.research.google.com/github/Calcious98/TIL/blob/master/Gradient_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 경사 하강법(Gradient Descent)

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # I. Machine( ) 정의
#
# * numpy Package

# %%
import numpy as np

# %% [markdown]
# * def Machine( )

# %% [markdown]
# ŷ = wx + b

# %%
def Machine(x, w, b):
    y_hat = (w * x) + b
    return y_hat

# %% [markdown]
# * x, w, b 객체 지정

# %%
x = np.array([1, 3, 5, 7, 9])
w = 2
b = 1

# %% [markdown]
# * Machine( ) 테스트

# %%
Machine(x, w, b)
# Out:
# array([ 3,  7, 11, 15, 19])

# %% [markdown]
# # II. Gradient( ) 정의
# * def Gradient( )

# %% [markdown]
# w 와 b 의 미분값을 구한다

# %%
def Gradient(x, y, w, b):
    y_hat = Machine(x, w, b)

    dw = np.mean((y - y_hat) * (-2 * x))
    db = np.mean((y - y_hat) * (-2))

    return dw, db

# %% [markdown]
# * Gradient( ) 테스트

# %%
y = np.array([2, 4, 6, 8, 10])

dw, db = Gradient(x, y, w, b)

# %%
print('dw is ', dw)
print('db is ', db)
# Out:
# dw is  66.0
# db is  10.0

# %% [markdown]
# # III. Learning( ) 정의
# * def Learning( )

# %% [markdown]
# w = 2 --> dw = 66 이면 거리가 너무 많이 이동해서 γ(step size) 를 이용

# %% [markdown]
# uw 는 w값이 경사하강을 통해 바뀐 값

# %%
def Learning(x, y, w, b, step):
    dw, db = Gradient(x, y, w, b)
    
    uw = w - step * dw
    ub = b - step * db
    
    return uw, ub

# %% [markdown]
# * Learning( ) 테스트

# %%
step = 0.05

uw, ub = Learning(x, y, w, b, step)

# %%
print('Updated_w is ', '%.3f' % uw)
print('Updated_b is ', '%.3f' % ub)
# Out:
# Updated_w is  -1.300
# Updated_b is  0.500

# %% [markdown]
# - w = 2 --> -1.3
# - b = 1 --> 0.5

# %% [markdown]
# # IV. testData.csv에 적용

# %% [markdown]
# * pandas & matplotlib Packages

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# * Read testData.csv
# - 데이터 읽어 오기

# %%
url = 'https://raw.githubusercontent.com/rusita-ai/pyData/master/testData.csv'

DATA = pd.read_csv(url)

# %% [markdown]
# * testData.csv Information

# %%
DATA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   inputs   5000 non-null   float64
#  1   outputs  5000 non-null   float64
# dtypes: float64(2)
# memory usage: 78.2 KB

# %%
DATA.head()
# Out:
#    inputs   outputs
# 0  0.2362  0.162367
# 1  0.9415  0.479356
# 2  0.3495  0.095733
# 3  0.3200 -0.111783
# 4  0.8335  0.386012

# %% [markdown]
# * testData.csv Visualization
#  - Distribution

# %%
plt.scatter(DATA.inputs, DATA.outputs, s = 0.5)
plt.show()

# %% [markdown]
# 리셋

# %%
w = 2
b = 3
step = 0.05

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 20번 학습

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * 1500번 학습 실행

# %%
for i in range(0, 1500):
    uw, ub = Learning(DATA.inputs, DATA.outputs, w, b, step)
    w = uw
    b = ub

# %%
print('Learned_w is ', '%.3f' % w)
print('Learned_b is ', '%.3f' % b)
# Out:
# Learned_w is  0.505
# Learned_b is  -0.170

# %% [markdown]
# * 학습결과 회귀선 그리기

# %%
X = np.linspace(0, 1, 100)
Y = (w * X) + b

plt.scatter(DATA.inputs, DATA.outputs, s = 0.3)
plt.plot(X, Y, '-r', linewidth = 1.5)
plt.show()

# %% [markdown]
# # V. Loss(MSE) Visualization

# %% [markdown]
# 오차(MSE)가 줄어드는 것을 보여준다

# %% [markdown]
# * Gradient( )에 MSE 추가

# %%
def Gradient(x, y, w, b):
    y_hat = Machine(x, w, b)
    
    dw = np.mean((y - y_hat) * (-2 * x))
    db = np.mean((y - y_hat) * (-2))
    MSE = np.mean((y - y_hat)**2)

    return dw, db, MSE

# %% [markdown]
# * Learning( )에 MSE 추가

# %%
def Learning(x, y, w, b, step):
    dw, db, MSE = Gradient(x, y, w, b)
    
    uw = w - step * dw
    ub = b - step * db

    return uw, ub, MSE

# %% [markdown]
# * 1500번 학습 실행

# %% [markdown]
# learning rate를 작게 만들어 학습 속도가 어떻게 바뀌는지 본다

# %% [markdown]
# 한번 학습할 때 마다 경사하강은 작아진다

# %% [markdown]
# 하지만 학습률이 잘못되면 오차가 커기게 된다

# %%
w = 2
b = 3
step = 0.001
mse = []

# %%
for i in range(0, 1500):
    uw, ub, MSE = Learning(DATA.inputs, DATA.outputs, w, b, step)

    w = uw
    b = ub
    mse.append(MSE)

# %% [markdown]
# * Loss(MSE) 감소 확인

# %%
mse[0:10]
# Out:
# [15.595575679087718,
#  15.51649361545252,
#  15.43781315527885,
#  15.359532259084672,
#  15.281648897745166,
#  15.204161052440112,
#  15.127066714601563,
#  15.050363885861781,
#  14.974050578001444,
#  14.8981248128981]

# %%
plt.plot(mse)
plt.show()

# %% [markdown]
# 확대: 앞에서 50개

# %%
plt.plot(mse[0:50], '.')
plt.show()

# %% [markdown]
# 확대: 뒤에서 50개 (줄어든 범위가 작아진다)

# %%
plt.plot(mse[1450:1500], '.')
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #
# #
# #
# # The End
# #
# #
# #
